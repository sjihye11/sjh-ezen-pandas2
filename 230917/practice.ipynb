# %%
import pandas as pd

# %%
corona = pd.read_csv('../csv/corona.csv')

# %%
corona.head(3)
# Out:
#    Unnamed: 0                 createDt  deathCnt  decideCnt  seq   stateDt  \
# 0           0  2022-06-08 09:09:05.982     24305   18188200  904  20220608
# 1           1  2022-06-07 09:09:00.897     24299   18174842  903  20220607
# 2           2  2022-06-06 09:00:06.734     24279   18168670  902  20220606
#
#   stateTime                 updateDt  accExamCnt  accDefRate
# 0     00:00                      NaN         NaN         NaN
# 1     00:00  2022-06-08 09:10:36.846         NaN         NaN
# 2     00:00  2022-06-08 09:10:50.441         NaN         NaN

# %%
corona.drop(['Unnamed: 0'], axis=1)
corona2 = corona.drop(['Unnamed: 0'], axis=1)

# %%
corona2
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0    2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
corona.head(1)
# Out:
#    Unnamed: 0                 createDt  deathCnt  decideCnt  seq   stateDt  \
# 0           0  2022-06-08 09:09:05.982     24305   18188200  904  20220608
#
#   stateTime updateDt  accExamCnt  accDefRate
# 0     00:00      NaN         NaN         NaN

# %%
corona.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %%
corona
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0    2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
corona.head(1)
# Out:
#                   createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0  2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
#
#   updateDt  accExamCnt  accDefRate
# 0      NaN         NaN         NaN

# %%
corona.drop([0], axis=0)
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# 5    2022-06-03 09:08:18.729     24229   18141775  899  20220603     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
df=corona

# %%
df
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0    2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
df=corona.drop([0],axis=0)

# %%
df
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# 5    2022-06-03 09:08:18.729     24229   18141775  899  20220603     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
df=corona.copy()
df
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0    2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
df
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0    2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
df=df.drop([0],axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\sjh\sjh-ezen-pandas2\230917\practice.ipynb 셀 17 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/sjh/sjh-ezen-pandas2/230917/practice.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> df=df.drop([0],axis=0)
#
# File c:\Users\EZEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
# ...

# %%
df
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# 5    2022-06-03 09:08:18.729     24229   18141775  899  20220603     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
df.drop([0],axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\sjh\sjh-ezen-pandas2\230917\practice.ipynb 셀 19 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/sjh/sjh-ezen-pandas2/230917/practice.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> df.drop([0],axis=0,inplace=True)
#
# File c:\Users\EZEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
# ...

# %%
corona
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0    2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
corona = df

# %%
corona
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0    2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
corona.head(2)
# Out:
#                   createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0  2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
# 1  2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
#
#                   updateDt  accExamCnt  accDefRate
# 0                      NaN         NaN         NaN
# 1  2022-06-08 09:10:36.846         NaN         NaN

# %%
corona.drop([0],axis=0)
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# 5    2022-06-03 09:08:18.729     24229   18141775  899  20220603     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
df=corona

# %%
df.drop([0],axis=0,inplace=True)

# %%
df
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# 5    2022-06-03 09:08:18.729     24229   18141775  899  20220603     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
corona
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# 5    2022-06-03 09:08:18.729     24229   18141775  899  20220603     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
df = corona.copy()

# %%
df
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# 5    2022-06-03 09:08:18.729     24229   18141775  899  20220603     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
df.drop([1],axis=0, inplace=True)

# %%
df
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# 5    2022-06-03 09:08:18.729     24229   18141775  899  20220603     00:00
# 6    2022-06-02 08:58:19.746     24212   18129236  898  20220602     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
corona
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# 5    2022-06-03 09:08:18.729     24229   18141775  899  20220603     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
df.head(1)
# Out:
#                   createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 2  2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
#
#                   updateDt  accExamCnt  accDefRate
# 2  2022-06-08 09:10:50.441         NaN         NaN

# %%
df.columns
# Out:
# Index(['createDt', 'deathCnt', 'decideCnt', 'seq', 'stateDt', 'stateTime',
#        'updateDt', 'accExamCnt', 'accDefRate'],
#       dtype='object')

# %%
df.columns=['등록일시','총사망자','총확진자','게시글번호','기준일','기준시간','수정일시','누적의심자','누적확진자']

# %%
df.head(5)
# Out:
#                       등록일시   총사망자      총확진자  게시글번호       기준일   기준시간  \
# 2  2022-06-06 09:00:06.734  24279  18168670    902  20220606  00:00
# 3  2022-06-05 08:53:19.426  24258  18163648    901  20220605  00:00
# 4  2022-06-04 08:56:49.219  24238  18153814    900  20220604  00:00
# 5  2022-06-03 09:08:18.729  24229  18141775    899  20220603  00:00
# 6  2022-06-02 08:58:19.746  24212  18129236    898  20220602  00:00
#
#                       수정일시  누적의심자  누적확진자
# 2  2022-06-08 09:10:50.441    NaN    NaN
# 3  2022-06-08 09:11:04.758    NaN    NaN
# 4  2022-06-08 09:11:26.303    NaN    NaN
# 5  2022-06-08 09:11:38.938    NaN    NaN
# 6  2022-06-08 09:11:51.985    NaN    NaN

# %%
# 데이터프레임에서 특정 컬럼을 기준으로 정렬을 변경
# sort_values([{기준 컬럼}, ascending=bool, inplace=bool])
df.sort_values(['등록일시'],ascending=True,inplace=True)

# %%
df
# Out:
#                         등록일시   총사망자      총확진자  게시글번호       기준일   기준시간  \
# 819  2020-03-10 00:00:00.000     54      7513     51  20200310  00:00
# 818  2020-03-11 00:00:00.000     60      7755     52  20200311  00:00
# 817  2020-03-12 00:00:00.000     66      7869     53  20200312  00:00
# 816  2020-03-13 00:00:00.000     67      7979     54  20200313  00:00
# 815  2020-03-14 00:00:00.000     72      8086     55  20200314  00:00
# ..                       ...    ...       ...    ...       ...    ...
# 6    2022-06-02 08:58:19.746  24212  18129236    898  20220602  00:00
# 5    2022-06-03 09:08:18.729  24229  18141775    899  20220603  00:00
# 4    2022-06-04 08:56:49.219  24238  18153814    900  20220604  00:00
# 3    2022-06-05 08:53:19.426  24258  18163648    901  20220605  00:00
# 2    2022-06-06 09:00:06.734  24279  18168670    902  20220606  00:00
#
#                         수정일시     누적의심자     누적확진자
# 819   2021-10-07 10:30:51.51  210144.0  3.919308
# ...

# %%
df.reset_index()
# Out:
#      index                     등록일시   총사망자      총확진자  게시글번호       기준일   기준시간  \
# 0      819  2020-03-10 00:00:00.000     54      7513     51  20200310  00:00
# 1      818  2020-03-11 00:00:00.000     60      7755     52  20200311  00:00
# 2      817  2020-03-12 00:00:00.000     66      7869     53  20200312  00:00
# 3      816  2020-03-13 00:00:00.000     67      7979     54  20200313  00:00
# 4      815  2020-03-14 00:00:00.000     72      8086     55  20200314  00:00
# ..     ...                      ...    ...       ...    ...       ...    ...
# 813      6  2022-06-02 08:58:19.746  24212  18129236    898  20220602  00:00
# 814      5  2022-06-03 09:08:18.729  24229  18141775    899  20220603  00:00
# 815      4  2022-06-04 08:56:49.219  24238  18153814    900  20220604  00:00
# 816      3  2022-06-05 08:53:19.426  24258  18163648    901  20220605  00:00
# 817      2  2022-06-06 09:00:06.734  24279  18168670    902  20220606  00:00
#
# ...

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                         등록일시   총사망자      총확진자  게시글번호       기준일   기준시간  \
# 0    2020-03-10 00:00:00.000     54      7513     51  20200310  00:00
# 1    2020-03-11 00:00:00.000     60      7755     52  20200311  00:00
# 2    2020-03-12 00:00:00.000     66      7869     53  20200312  00:00
# 3    2020-03-13 00:00:00.000     67      7979     54  20200313  00:00
# 4    2020-03-14 00:00:00.000     72      8086     55  20200314  00:00
# ..                       ...    ...       ...    ...       ...    ...
# 813  2022-06-02 08:58:19.746  24212  18129236    898  20220602  00:00
# 814  2022-06-03 09:08:18.729  24229  18141775    899  20220603  00:00
# 815  2022-06-04 08:56:49.219  24238  18153814    900  20220604  00:00
# 816  2022-06-05 08:53:19.426  24258  18163648    901  20220605  00:00
# 817  2022-06-06 09:00:06.734  24279  18168670    902  20220606  00:00
#
#                         수정일시     누적의심자     누적확진자
# 0     2021-10-07 10:30:51.51  210144.0  3.919308
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 818 entries, 0 to 817
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   등록일시    818 non-null    object
#  1   총사망자    818 non-null    int64
#  2   총확진자    818 non-null    int64
#  3   게시글번호   818 non-null    int64
#  4   기준일     818 non-null    int64
#  5   기준시간    818 non-null    object
#  6   수정일시    816 non-null    object
#  7   누적의심자   692 non-null    float64
#  8   누적확진자   623 non-null    float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 57.6+ KB

# %%
# 결측치를 보여줘
# df.info()
# df.isna()
df.isna()
# Out:
#       등록일시   총사망자   총확진자  게시글번호    기준일   기준시간   수정일시  누적의심자  누적확진자
# 0    False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 813  False  False  False  False  False  False  False   True   True
# 814  False  False  False  False  False  False  False   True   True
# 815  False  False  False  False  False  False  False   True   True
# 816  False  False  False  False  False  False  False   True   True
# 817  False  False  False  False  False  False  False   True   True
#
# [818 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# 등록일시       0
# 총사망자       0
# 총확진자       0
# 게시글번호      0
# 기준일        0
# 기준시간       0
# 수정일시       2
# 누적의심자    126
# 누적확진자    195
# dtype: int64

# %%
df['누적의심자']
# Out:
# 0      210144.0
# 1      222395.0
# 2      234998.0
# 3      248647.0
# 4      261335.0
#          ...
# 813         NaN
# 814         NaN
# 815         NaN
# 816         NaN
# 817         NaN
# Name: 누적의심자, Length: 818, dtype: float64

# %%
df['누적의심자'].fillna(method='bfill')
# Out:
# C:\Users\EZEN\AppData\Local\Temp\ipykernel_5024\861005942.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['누적의심자'].fillna(method='bfill')
# 0      210144.0
# 1      222395.0
# 2      234998.0
# 3      248647.0
# 4      261335.0
#          ...
# 813         NaN
# 814         NaN
# 815         NaN
# 816         NaN
# 817         NaN
# Name: 누적의심자, Length: 818, dtype: float64

# %%
df['누적의심자'].fillna(method='ffill')
# 어느 순간 결측치가 있으면 그 전의 데이터를 갖고 가서 쓰겠지
# 그러면 최근의 데이터를 계속 보여줄거야. 확인했으니까 이제 대입하자.
# Out:
# C:\Users\EZEN\AppData\Local\Temp\ipykernel_5024\3452700325.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['누적의심자'].fillna(method='ffill')
# 0        210144.0
# 1        222395.0
# 2        234998.0
# 3        248647.0
# 4        261335.0
#           ...
# 813    21518073.0
# 814    21518073.0
# 815    21518073.0
# 816    21518073.0
# 817    21518073.0
# Name: 누적의심자, Length: 818, dtype: float64

# %%
df['누적의심자']=df['누적의심자'].fillna(method='ffill')
# Out:
# C:\Users\EZEN\AppData\Local\Temp\ipykernel_5024\3072566723.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['누적의심자']=df['누적의심자'].fillna(method='ffill')

# %%
df.isna().sum()
# Out:
# 등록일시       0
# 총사망자       0
# 총확진자       0
# 게시글번호      0
# 기준일        0
# 기준시간       0
# 수정일시       2
# 누적의심자      0
# 누적확진자    195
# dtype: int64

# %%
df.head(3)
# Out:
#                       등록일시  총사망자  총확진자  게시글번호       기준일   기준시간  \
# 0  2020-03-10 00:00:00.000    54  7513     51  20200310  00:00
# 1  2020-03-11 00:00:00.000    60  7755     52  20200311  00:00
# 2  2020-03-12 00:00:00.000    66  7869     53  20200312  00:00
#
#                      수정일시     누적의심자     누적확진자
# 0  2021-10-07 10:30:51.51  210144.0  3.919308
# 1  2021-10-07 10:30:51.51  222395.0  3.804175
# 2  2021-10-07 10:30:51.51  234998.0  3.621744

# %%
# 54번부터 다시
